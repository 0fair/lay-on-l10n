# %%
import pandas as pd

# %%
df = pd.read_json("./datasets/books.jsn")

# %%
df = pd.read_json("./datasets/utf8/books.jsn")

# %%
df[df.parentId != 0].head()
# Out:
#           id  parentId         bbk  \
# 144  1402788   1575116  63.3(4Гем)
# 382    11233     11232          92
# 392   221103    121077          95
# 421   993627    422634        60я2
# 423  1158825    422634          92
#
#                                                  title  year  parentAuthor  \
# 144         Гитлер : биография. [Кн. 1-4]. Путь наверх  2006        115287
# 382  Чудеса и приключения : литературно-художествен...  2018             0
# 392  Чудеса и приключения детям : литературно-позна...  2018             0
# 421  Энциклопедия для детей : Т. 21, ч. 1. Общество...  2005             0
# 423  Энциклопедия для детей : Т.21: Ч.1. Общество: ...  2005             0
#
#                                           contribution parentNumberOfPart  \
# 144
# 382
# 392
# 421  Ред.коллегия : М. Аксёнова  ,В. Володин , М. Б...
# 423                                гл. ред. В. Володин
#
#               isbn                                         annotation  ...  \
# ...

# %%
df[df.title.str.contains('Гарри Поттер')].head(200)
# Out:
#            id  parentId              bbk  \
# 296    256714         0            84(3)
# 346   1247997         0         84(4Вел)
# 397    881204         0         84(4Вел)
# 398   1866639         0         84(4Вел)
# 1246  1001772         0         84(4Вел)
# 1273  1522409         0         84(4Вел)
# 1274    95781         0         84(4Вел)
# 1275   202322         0         84(4Вел)
# 1309  1524259         0         84(4Вел)
# 1836  1277864         0         84(4Вел)
# 1838    64857         0         84(4Вел)
# 2321  2108799         0      84(4Вел)-44
# 2322  1628305         0               84
# 2323  1047497         0         84(4Вел)
# 2324   980303         0  84(3); 84(4Вел)
# 2791   257912         0               84
# 3755  1951720         0        84(3)Англ
# 4086  1029999         0               84
# 4087  1072899         0         84(4Вел)
# 4088  2303890         0          84.4Вел
# 4269   232489         0         84(4Вел)
# 4375   432256         0         84(4Вел)
# ...

# %%
df[df.parentYear != ''].head(20).parentYear
# Out:
# 144          2006
# 382         1991-
# 392          2007
# 421         1993-
# 423         1993-
# 427         1993-
# 430         1999-
# 455         1993-
# 460         1993-
# 497         1993-
# 583         2017-
# 613         2020-
# 708          2019
# 772        2019 -
# 777          1965
# 806     1978-1985
# 901          1963
# 1015         1986
# 1016         1981
# 1019         1981
# Name: parentYear, dtype: object

# %%
df.language_name.unique()
# Out:
# array(['Русский', None, 'Английский', 'Латинский',
#        'Греческий (новогреческий)', 'Немецкий'], dtype=object)

# %%
df.author_dates.unique()
# Out:
# array(['1821-1881', '1965-', '1944-', '1949-', '1956-', None, '1920-2012',
#        '1969-', '1947-', '1971-', '1977-', '1964-', '1963-', '1975-',
#        '1982-', '1978-', '1927-2014', '1960-', '1991-', '1973-',
#        '1903-1979', '1976', '1938-', '1904 - 1999', '1976-', '1944-2017',
#        '1948-', '1914-2001', '1912-1990', '1966-', '1962-', '1972',
#        '1946-', '1858-1940', '1923-2013', '1799-1837', '1849-1924',
#        '1853-1921', '1818-1883', '1859-1930', '1848-1908', '1945 -',
#        '1936-', '1967-', '1933-', '1922-1994', '1952', '1972-',
#        '1934-2012', '1879-1965', '1985-', '1941-', '1979-', '1930-',
#        '1928-', '1970 -', '1910-1967', '1974-', '1981-', '1929-', '1950',
#        '1938-1995', '1907-2002', '1923-2019', '1867-1957', '1929-1997',
#        '1936-2018', '1963', '1978 -', '1928-1996', '1942-', '1954-',
#        '1924-1997', '1858-1924', '1980-', '1984-', '1958', '1981',
#        '1985 -', '1865-1936', '1957-', '1965-2016', '1954-2017',
# ...
